# %% [markdown]
# <a href="https://colab.research.google.com/github/bearbearyu1223/llm-fine-tuning-playground/blob/main/fine_tune_whisper_with_LoRA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fine-Tune Whisper with LoRA

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Prepare the Dev Enviroment

# %% [markdown]
# First of all, let's try to secure a compute instance with GPU for training. The script below can be used to veriy if we have assigned with a GPU and also what is its specifications.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip install datasets>=2.6.1
# !pip install git+https://github.com/huggingface/transformers
# !pip install librosa
# !pip install evaluate>=0.30
# !pip install jiwer
# !pip install gradio
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-hcfc0fee
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-hcfc0fee
#   Resolved https://github.com/huggingface/transformers to commit 4ab5fb8941a38d172b3883c152c34ae2a0b83a68
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-4.37.0.dev0-py3-none-any.whl size=8311516 sha256=2d2f170fab172c68a47e7cd5bd6f32b8b705ab4e3b0a02dd7ad66343ea2f9c54
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ocukirgm/wheels/c0/14/d6/6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# ...

# %% [markdown]
# We will push the model checkpoints to  Hugging Face Hub once the training experiment is completed, so we need link this notebook to Hugging Face account, which can be achieved by entering the Hugging Face aunthentication token via the scripts below.

# %%
from huggingface_hub import notebook_login

notebook_login()

# %% [markdown]
# ## Prepare the dataset for fine-tuning

# %% [markdown]
# We use the low-resource language zh-TW from [mozilla-foundation/common_voice_16_0](https://huggingface.co/datasets/mozilla-foundation/common_voice_16_0/viewer/yue)  for the fine-tuning task.

# %%
from datasets import load_dataset, DatasetDict
